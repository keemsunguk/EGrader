# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('/Users/keemsunguk/Projects/EssayGrader/')

# %%
import json
import re
import spacy
from spacy import displacy

# %%
import stanza
from spacy_stanza import StanzaLanguage

# %%
from egrader.preprocess import Preprocess
from egrader.db_util import DBUtil

# %%
prep = Preprocess(None)
# Out:
# Loaded model 'en_core_web_lg'

# %%
db_util = DBUtil(local_db=True)
db_util.describe_db()
# Out:
# ==== LOCAL ====
# ['essay']
# Total Essay: 30498
# Total SAT: 3310
# Total TOEFL: 4614
# Total GRE: 6688
# ==== REMOTE ====
# ['essays']
# Total Essay: 29883
# Total SAT: 3275
# Total TOEFL: 4613
# Total GRE: 6662

# %% [markdown]
# # logical test

# %%
toefl_essay = [e for e in db_util.remote_ec.find({'$and': [{'type': 'TOEFL'}, {'rate': {'$gte': 0}}]})]

# %%
toefl_essay[0]['recno']
# Out:
# 458

# %%
sent = ' '.join([t['text'] for t in toefl_essay[0]['sentences'][0]])

# %%
snlp = stanza.Pipeline(lang="en")
nlp = StanzaLanguage(snlp)
# Out:
# 2020-03-25 21:41:13 INFO: Loading these models for language: en (English):
# ...
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | ner       | ontonotes |
# ...
#
# 2020-03-25 21:41:13 INFO: Use device: cpu
# 2020-03-25 21:41:13 INFO: Loading: tokenize
# 2020-03-25 21:41:13 INFO: Loading: pos
# 2020-03-25 21:41:14 INFO: Loading: lemma
# 2020-03-25 21:41:14 INFO: Loading: depparse
# 2020-03-25 21:41:15 INFO: Loading: ner
# 2020-03-25 21:41:16 INFO: Done loading processors!

# %%
doc = nlp(sent)

# %%
from spacy import displacy
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="62c28f295b384cdc9922e94f9b2d8090-0" class="displacy" width="2500" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Having</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">new</tspan>
# ...

# %%
nlp3 = spacy.load('en_core_web_lg')

# %%
sp_doc = nlp3(sent)

# %%
displacy.render(sp_doc, style='dep', jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="10f209d067a347098a24e08c4a774561-0" class="displacy" width="2500" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Having</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">new</tspan>
# ...

# %%
toefl_essay[0]['sentences'][0]
# Out:
# [{'id': '1',
#   'text': 'Having',
#   'lemma': 'have',
#   'upos': 'VERB',
#   'xpos': 'VBG',
#   'feats': 'VerbForm=Ger',
#   'head': 7,
#   'deprel': 'csubj',
#   'misc': 'start_char=0|end_char=6'},
#  {'id': '2',
#   'text': 'a',
#   'lemma': 'a',
#   'upos': 'DET',
#   'xpos': 'DT',
#   'feats': 'Definite=Ind|PronType=Art',
#   'head': 5,
#   'deprel': 'det',
#   'misc': 'start_char=7|end_char=8'},
#  {'id': '3',
#   'text': 'new',
#   'lemma': 'new',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': 'Degree=Pos',
#   'head': 5,
#   'deprel': 'amod',
#   'misc': 'start_char=9|end_char=12'},
#  {'id': '4',
#   'text': 'large',
#   'lemma': 'large',
#   'upos': 'ADJ',
#   'xpos': 'JJ',
#   'feats': 'Degree=Pos',
#   'head': 5,
#   'deprel': 'amod',
#   'misc': 'start_char=13|end_char=18'},
#  {'id': '5',
#   'text': 'factory',
#   'lemma': 'factory',
#   'upos': 'NOUN',
#   'xpos': 'NN',
#   'feats': 'Number=Sing',
#   'head': 1,
#   'deprel': 'obj',
# ...
